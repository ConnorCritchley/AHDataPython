# %%
import pandas as pd

# %%
# %time csv = csv_df = pd.read_csv("../data/wta/wta_matches_2022.csv")
csv_df.head()
# Out:
# CPU times: user 17 ms, sys: 5.42 ms, total: 22.5 ms
# Wall time: 25.3 ms
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2022-2014   Adelaide 1    Hard         30             P      20220103
# 1  2022-2014   Adelaide 1    Hard         30             P      20220103
# 2  2022-2014   Adelaide 1    Hard         30             P      20220103
# 3  2022-2014   Adelaide 1    Hard         30             P      20220103
# 4  2022-2014   Adelaide 1    Hard         30             P      20220103
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     202458           1          NaN  ...    19.0     16.0
# 1        299     202458           1          NaN  ...    39.0     27.0
# 2        298     214981           7          NaN  ...    45.0     29.0
# 3        297     202458           1          NaN  ...    54.0     34.0
# 4        296     216347           5          NaN  ...    45.0     30.0
#
# ...

# %%
# %time tsv = tsv_df = pd.read_csv("../data/wta/wta_matches_2022.tsv", sep='\t')
tsv_df.head()
# Out:
# CPU times: user 17.6 ms, sys: 4.36 ms, total: 21.9 ms
# Wall time: 22.4 ms
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2022-2014   Adelaide 1    Hard         30             P      20220103
# 1  2022-2014   Adelaide 1    Hard         30             P      20220103
# 2  2022-2014   Adelaide 1    Hard         30             P      20220103
# 3  2022-2014   Adelaide 1    Hard         30             P      20220103
# 4  2022-2014   Adelaide 1    Hard         30             P      20220103
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     202458           1          NaN  ...    19.0     16.0
# 1        299     202458           1          NaN  ...    39.0     27.0
# 2        298     214981           7          NaN  ...    45.0     29.0
# 3        297     202458           1          NaN  ...    54.0     34.0
# 4        296     216347           5          NaN  ...    45.0     30.0
#
# ...

# %%
# %time xl = xl_df = pd.read_excel("../data/wta/wta_matches_2022.xlsx")
xl_df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2022-2014   Adelaide 1    Hard         30             P      20220103
# 1  2022-2014   Adelaide 1    Hard         30             P      20220103
# 2  2022-2014   Adelaide 1    Hard         30             P      20220103
# 3  2022-2014   Adelaide 1    Hard         30             P      20220103
# 4  2022-2014   Adelaide 1    Hard         30             P      20220103
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     202458           1          NaN  ...    19.0     16.0
# 1        299     202458           1          NaN  ...    39.0     27.0
# 2        298     214981           7          NaN  ...    45.0     29.0
# 3        297     202458           1          NaN  ...    54.0     34.0
# 4        296     216347           5          NaN  ...    45.0     30.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank winner_rank_points  \
# ...

# %%
# %time pq = pq_df = pd.read_parquet("../data/wta/wta_matches_2022.parquet", engine='pyarrow')
pq_df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2022-2014   Adelaide 1    Hard         30             P      20220103
# 1  2022-2014   Adelaide 1    Hard         30             P      20220103
# 2  2022-2014   Adelaide 1    Hard         30             P      20220103
# 3  2022-2014   Adelaide 1    Hard         30             P      20220103
# 4  2022-2014   Adelaide 1    Hard         30             P      20220103
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     202458           1         None  ...    19.0     16.0
# 1        299     202458           1         None  ...    39.0     27.0
# 2        298     214981           7         None  ...    45.0     29.0
# 3        297     202458           1         None  ...    54.0     34.0
# 4        296     216347           5         None  ...    45.0     30.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank winner_rank_points  \
# ...
